# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data = {'series1':[1,3,4,3,5],
                'series2':[2,4,5,2,4],
                'series3':[3,2,3,1,3]}
df = pd.DataFrame(data)
x = np.arange(5)
plt.axis([0,5,0,7])
plt.plot(x,df)
plt.legend(data, loc=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), None)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Input In [1], in <cell line: 11>()
#       9 x = np.arange(5)
#      10 plt.axis([0,5,0,7])
# ---> 11 plt.plot(x,df)
# ...

# %%
df = pd.read_csv('Sacramentorealestatetransactions.csv')

tmp = df[['beds', 'baths', 'sq__ft']]
plt.plot(tmp)
plt.legend(tmp)

# %% [markdown]
# ### 무작위 정수 10개를 구하여 Bar차트 그리기
# ### 그 위에 무작위 정수 10개를 다시 구하녀 Line 차트 그리기(적색)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = range(10)
y = np.random.randint(1,11, 10)

y2 = np.random.randint(1,11, 10)

plt.bar(x,y)
plt.plot(x,y2,'r')

plt.show()

# %%
# 포물선 그리기
x = np.arange(-5, 5, 0.1)
x = np.linspace(-5, 5, 100)
y = x**2

plt.plot(x,y)
plt.show()

# %%
# 포물선 그리기
x = np.arange(-5, 5, 0.1)
x = np.linspace(-5, 5, 100)

w = 0.1
b = 0

y = w * (x**2) + b
plt.plot(x,y)
plt.show()

# %%
a = 1
b = 0

x = np.linspace(-5, 5, 100)
y = a*x + b

plt.axis([0,5,0,5])
plt.plot(x,y,'r')
plt.show()

# %% [markdown]
# ### 기울기가 다른 3개의 직선을 차트에 표시하고 각 직선의 기울기를 범례에 표시

# %%
a = 1
b = 0

x = np.linspace(-5, 5, 100)
y1 = 1*x + b
y2 = 2*x + b
y3 = 0.5*x + b

data = {'y1' : 1*x + b,
       'y2' : 2*x + b,
       'y3' : 0.5*x + b,}


plt.axis([0,5,0,5])
plt.plot(x,y,'r')
plt.plot(x,y2,'b')
plt.plot(x,y3,'g')
plt.legend(['$y1$', '$y2$','$y3$'])
plt.show()

# %%
plt.plot([1,2,3,4,5], 'o')

# %%
x = np.arange(5)
y = np.random.randint(1, 10, 5)
plt.scatter(x,y)
plt.show()

# %%
x = np.arange(5)
y = np.random.randint(1, 10, 5)
plt.scatter(x,y, c=['r', 'g', 'b', 'k', 'y']) # c=(1,0,0) : RGB 컬러채널
plt.show()

# %% [markdown]
# ## 무작위 정수 100개준비(0~100), 정규분포
# 산점도에 표시
# 색상 3가지 분류
# - 0~33 : red
# - 34~66 : green
# - 67~100 : blue

# %%
x = np.arange(100)
y = np.random.normal(50, 25, 100)
c = [(1,0,0) if v<=33 else (0,1,0) if v>33 and v<=66 else (0,0,1) for v in y]
s = [30 if v<=33 else 40 if v>33 and v<=66 else 80 for v in y]
m = ["v" if v<=33 else "s" if v>33 and v<=66 else "<" for v in y]
# c = []
# for v in y:
#     if v<=33:
#         c.append((1,0,0))
#     elif v>33 and v<=66:
#         c.append((0,1,0))
#     else:
#         c.append((0,0,1))
plt.scatter(x, y, c=c, s=s, marker=m)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/markers.py:326, in MarkerStyle._set_marker(self, marker)
#     325 try:
# --> 326     Path(marker)
#     327     self._marker_function = self._set_vertices
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/path.py:129, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     101 """
#     102 Create a new path with the given vertices and codes.
#     103
#    (...)
#     127     and codes as read-only arrays.
#     128 """
# --> 129 vertices = _to_unmasked_float_array(vertices)
#     130 _api.check_shape((None, 2), vertices=vertices)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1298, in _to_unmasked_float_array(x)
#    1297 else:
# -> 1298     return np.asarray(x, float)
#
# ...
